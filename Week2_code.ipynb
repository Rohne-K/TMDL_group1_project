# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohne-K/TMDL_group1_project/blob/main/Week2_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/code turing')

# %%
import pandas as pd

# %%
df = pd.read_csv("heart-attack-risk-prediction-dataset.csv")

# %%
df
# Out:
#            Age  Cholesterol  Heart rate  Diabetes  Family History  Smoking  \
# 0     0.595506     0.314286    0.047663       0.0             0.0      1.0
# 1     0.595506     0.096429    0.047663       1.0             1.0      1.0
# 2     0.595506     0.189286    0.047663       0.0             0.0      1.0
# 3     0.078652     0.960714    0.071494       1.0             1.0      1.0
# 4     0.078652     0.792857    0.071494       1.0             0.0      1.0
# ...        ...          ...         ...       ...             ...      ...
# 9646  0.404494     0.499780    0.091659       NaN             NaN      NaN
# 9647  0.235955     0.499780    0.049496       NaN             NaN      NaN
# 9648  0.348315     0.499780    0.088909       NaN             NaN      NaN
# 9649  0.370787     0.499780    0.067828       NaN             NaN      NaN
# 9650  0.797753     0.499780    0.084326       NaN             NaN      NaN
#
# ...

# %%
df_diet3 = df[df['Diet'] == 3]
df_diet3
# Out:
#            Age  Cholesterol  Heart rate  Diabetes  Family History  Smoking  \
# 9377  0.516854      0.49978    0.065995       NaN             NaN      NaN
# 9378  0.516854      0.49978    0.065995       NaN             NaN      NaN
# 9379  0.516854      0.49978    0.065995       NaN             NaN      NaN
# 9380  0.382022      0.49978    0.105408       NaN             NaN      NaN
# 9381  0.370787      0.49978    0.042163       NaN             NaN      NaN
# ...        ...          ...         ...       ...             ...      ...
# 9646  0.404494      0.49978    0.091659       NaN             NaN      NaN
# 9647  0.235955      0.49978    0.049496       NaN             NaN      NaN
# 9648  0.348315      0.49978    0.088909       NaN             NaN      NaN
# 9649  0.370787      0.49978    0.067828       NaN             NaN      NaN
# 9650  0.797753      0.49978    0.084326       NaN             NaN      NaN
#
# ...

# %%
import numpy as np

display(df.describe())
df.info()
# Out:
#                Age  Cholesterol   Heart rate     Diabetes  Family History  \
# count  9651.000000  9651.000000  9651.000000  9377.000000     9377.000000
# mean      0.450254     0.499780     0.050756     0.652554        0.488749
# std       0.231154     0.284461     0.024922     0.476184        0.499900
# min       0.000000     0.000000     0.000000     0.000000        0.000000
# 25%       0.258427     0.264286     0.035289     0.000000        0.000000
# 50%       0.460674     0.499780     0.050412     1.000000        0.000000
# 75%       0.640449     0.739286     0.065995     1.000000        1.000000
# max       1.000000     1.000000     1.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  9377.000000  9377.000000          9377.000000              9651.000000
# mean      0.902421     0.500160             0.600192                 0.502110
# ...
